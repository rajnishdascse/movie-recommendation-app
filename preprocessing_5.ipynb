# %% [markdown]
# <a href="https://colab.research.google.com/github/rajnishdascse/movie-recommendation-app/blob/main/preprocessing_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Extracting features of 2021 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                   Title  \
# 0     JANUARY        1.0     Shadow in the Cloud
# 1     JANUARY       13.0         The White Tiger
# 2     JANUARY       14.0             Locked Down
# 3     JANUARY       15.0                 The Dig
# 4     JANUARY       15.0        Outside the Wire
# ..        ...        ...                     ...
# 353  DECEMBER       25.0  The Tragedy of Macbeth
# 354  DECEMBER       25.0    A Journal for Jordan
# 355  DECEMBER       25.0       American Underdog
# 356  DECEMBER       26.0                 Memoria
# 357  DECEMBER        NaN                     NaN
#
#                                     Production company  \
# 0                               Vertical Entertainment
# 1                                              Netflix
# 2                      HBO Max / Warner Bros. Pictures
# 3                          Netflix / Clerkenwell Films
# 4                                              Netflix
# ..                                                 ...
# 353                        Apple TV+ / A24 / IAC Films
# 354  Columbia Pictures / Escape Artists / Bron Studios
# 355                                          Lionsgate
# 356                                               Neon
# 357                                                NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 353  Joel Coen (director/screenplay); Denzel Washin...
# 354  Denzel Washington (director); Virgil Williams ...
# 355  Erwin brothers (directors); Jon Erwin, David A...
# 356  Apichatpong Weerasethakul (director/acreenplay...
# 357                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  NaN
# 2                                                  [3]
# 3                                                  [4]
# 4                                                  [5]
# ..                                                 ...
# 353                                                NaN
# 354                                                NaN
# 355                                                NaN
# 356                                                NaN
# 357                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 353  [271]
# 354  [272]
# 355  [273]
# 356  [274]
# 357    NaN
#
# [358 rows x 7 columns]

# %%
df_2021 = df[['Title','Cast and crew']]

# %%
df_2021
# Out:
#                       Title                                      Cast and crew
# 0       Shadow in the Cloud  Roseanne Liang (director/screenplay); Max Land...
# 1           The White Tiger  Ramin Bahrani (director/screenplay); Adarsh Go...
# 2               Locked Down  Doug Liman (director); Steven Knight (screenpl...
# 3                   The Dig  Simon Stone (director); Moira Buffini (screenp...
# 4          Outside the Wire  Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                      ...                                                ...
# 353  The Tragedy of Macbeth  Joel Coen (director/screenplay); Denzel Washin...
# 354    A Journal for Jordan  Denzel Washington (director); Virgil Williams ...
# 355       American Underdog  Erwin brothers (directors); Jon Erwin, David A...
# 356                 Memoria  Apichatpong Weerasethakul (director/acreenplay...
# 357                     NaN                                                NaN
#
# [358 rows x 2 columns]

# %%
# !pip install tmdbv3api
# Out:
# Collecting tmdbv3api
#   Downloading tmdbv3api-1.7.6-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from tmdbv3api) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->tmdbv3api) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->tmdbv3api) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->tmdbv3api) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->tmdbv3api) (1.24.3)
# Installing collected packages: tmdbv3api
# Successfully installed tmdbv3api-1.7.6

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '225ac8079ea25738ddc6a4c08757dd89'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2021
# Out:
#                       Title  \
# 0       Shadow in the Cloud
# 1           The White Tiger
# 2               Locked Down
# 3                   The Dig
# 4          Outside the Wire
# ..                      ...
# 353  The Tragedy of Macbeth
# 354    A Journal for Jordan
# 355       American Underdog
# 356                 Memoria
# 357                     NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 353  Joel Coen (director/screenplay); Denzel Washin...
# 354  Denzel Washington (director); Virgil Williams ...
# 355  Erwin brothers (directors); Jon Erwin, David A...
# 356  Apichatpong Weerasethakul (director/acreenplay...
# 357                                                NaN
#
#                               genres
# 0                  Horror Action War
# 1                              Drama
# 2                 Comedy Crime Drama
# 3                      Drama History
# 4    Thriller Action Science Fiction
# ..                               ...
# 353                        Drama War
# 354                    Drama Romance
# 355                            Drama
# 356            Drama Fantasy Mystery
# 357                           Comedy
#
# [358 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2021
# Out:
#                       Title  \
# 0       Shadow in the Cloud
# 1           The White Tiger
# 2               Locked Down
# 3                   The Dig
# 4          Outside the Wire
# ..                      ...
# 353  The Tragedy of Macbeth
# 354    A Journal for Jordan
# 355       American Underdog
# 356                 Memoria
# 357                     NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 353  Joel Coen (director/screenplay); Denzel Washin...
# 354  Denzel Washington (director); Virgil Williams ...
# 355  Erwin brothers (directors); Jon Erwin, David A...
# 356  Apichatpong Weerasethakul (director/acreenplay...
# 357                                                NaN
#
#                               genres  \
# 0                  Horror Action War
# 1                              Drama
# 2                 Comedy Crime Drama
# 3                      Drama History
# 4    Thriller Action Science Fiction
# ..                               ...
# 353                        Drama War
# 354                    Drama Romance
# 355                            Drama
# 356            Drama Fantasy Mystery
# 357                           Comedy
#
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 353                                          Joel Coen
# 354                                  Denzel Washington
# 355                                     Erwin brothers
# 356  Apichatpong Weerasethakul (director/acreenplay...
# 357                                                nan
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# 3                                       Carey Mulligan      Ralph Fiennes
# 4                                       Anthony Mackie       Damson Idris
# ..                                                 ...                ...
# 353                                  Denzel Washington  Frances McDormand
# 354                                  Michael B. Jordan       Chanté Adams
# 355                                       Zachary Levi        Anna Paquin
# 356  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
# 357                                                nan                NaN
#
#               actor_3_name
# 0             Beulah Koale
# 1    Priyanka Chopra Jonas
# 2         Stephen Merchant
# 3               Lily James
# 4            Emily Beecham
# ..                     ...
# 353          Bertie Carvel
# 354        Jalon Christian
# 355           Dennis Quaid
# 356         Jeanne Balibar
# 357                    NaN
#
# [358 rows x 7 columns]

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 353                                          Joel Coen
# 354                                  Denzel Washington
# 355                                     Erwin brothers
# 356  Apichatpong Weerasethakul (director/acreenplay...
# 357                                                nan
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# 3                                       Carey Mulligan      Ralph Fiennes
# 4                                       Anthony Mackie       Damson Idris
# ..                                                 ...                ...
# 353                                  Denzel Washington  Frances McDormand
# 354                                  Michael B. Jordan       Chanté Adams
# 355                                       Zachary Levi        Anna Paquin
# 356  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
# 357                                                nan                NaN
#
#               actor_3_name                           genres  \
# 0             Beulah Koale                Horror Action War
# 1    Priyanka Chopra Jonas                            Drama
# 2         Stephen Merchant               Comedy Crime Drama
# 3               Lily James                    Drama History
# 4            Emily Beecham  Thriller Action Science Fiction
# ..                     ...                              ...
# 353          Bertie Carvel                        Drama War
# 354        Jalon Christian                    Drama Romance
# 355           Dennis Quaid                            Drama
# 356         Jeanne Balibar            Drama Fantasy Mystery
# 357                    NaN                           Comedy
#
#                 movie_title
# 0       Shadow in the Cloud
# 1           The White Tiger
# 2               Locked Down
# 3                   The Dig
# 4          Outside the Wire
# ..                      ...
# 353  The Tragedy of Macbeth
# 354    A Journal for Jordan
# 355       American Underdog
# 356                 Memoria
# 357                     NaN
#
# [358 rows x 6 columns]

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']

# %%
new_df21 = new_df21.dropna(how='any')

# %%
new_df21['movie_title'] = new_df21['movie_title'].str.lower()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df21
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 352                                     Matthew Vaughn
# 353                                          Joel Coen
# 354                                  Denzel Washington
# 355                                     Erwin brothers
# 356  Apichatpong Weerasethakul (director/acreenplay...
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# 3                                       Carey Mulligan      Ralph Fiennes
# 4                                       Anthony Mackie       Damson Idris
# ..                                                 ...                ...
# 352                                      Ralph Fiennes     Gemma Arterton
# 353                                  Denzel Washington  Frances McDormand
# 354                                  Michael B. Jordan       Chanté Adams
# 355                                       Zachary Levi        Anna Paquin
# 356  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#               actor_3_name                                 genres  \
# 0             Beulah Koale                      Horror Action War
# 1    Priyanka Chopra Jonas                                  Drama
# 2         Stephen Merchant                     Comedy Crime Drama
# 3               Lily James                          Drama History
# 4            Emily Beecham        Thriller Action Science Fiction
# ..                     ...                                    ...
# 352             Rhys Ifans  Action Adventure Thriller War Mystery
# 353          Bertie Carvel                              Drama War
# 354        Jalon Christian                          Drama Romance
# 355           Dennis Quaid                                  Drama
# 356         Jeanne Balibar                  Drama Fantasy Mystery
#
#                 movie_title                                               comb
# 0       shadow in the cloud  Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1           the white tiger  Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 2               locked down  Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# 3                   the dig  Carey Mulligan Ralph Fiennes Lily James Simon ...
# 4          outside the wire  Anthony Mackie Damson Idris Emily Beecham Mika...
# ..                      ...                                                ...
# 352          the king's man  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 353  the tragedy of macbeth  Denzel Washington Frances McDormand Bertie Car...
# 354    a journal for jordan  Michael B. Jordan Chanté Adams Jalon Christian...
# 355       american underdog  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 356                 memoria  Apichatpong Weerasethakul (director/acreenplay...
#
# [332 rows x 7 columns]

# %%
old_df = pd.read_csv('main_data.csv')

# %%
old_df
# Out:
#          director_name     actor_1_name     actor_2_name       actor_3_name  \
# 0        John Lasseter        Tom Hanks        Tim Allen        Don Rickles
# 1         Joe Johnston   Robin Williams    Jonathan Hyde      Kirsten Dunst
# 2        Howard Deutch   Walter Matthau      Jack Lemmon        Ann-Margret
# 3      Forest Whitaker  Whitney Houston   Angela Bassett     Loretta Devine
# 4        Charles Shyer     Steve Martin     Diane Keaton       Martin Short
# ...                ...              ...              ...                ...
# 36982  Joseph Kosinski       Tom Cruise     Miles Teller  Jennifer Connelly
# 36983    Joel Crawford     Nicolas Cage       Emma Stone      Ryan Reynolds
# 36984      Liesl Tommy  Jennifer Hudson  Forest Whitaker      Marlon Wayans
# 36985     Ridley Scott       Matt Damon      Adam Driver        Jodie Comer
# 36986  Paul Greengrass        Tom Hanks    Helena Zengel    Neil Sandilands
#
#                            genres                  movie_title  \
# 0         Animation Comedy Family                    toy story
# 1        Adventure Fantasy Family                      jumanji
# 2                  Romance Comedy             grumpier old men
# 3            Comedy Drama Romance            waiting to exhale
# 4                          Comedy  father of the bride part ii
# ...                           ...                          ...
# 36982                Action Drama            top gun: maverick
# 36983  Animation Adventure Family                 the croods 2
# 36984                 Music Drama                      respect
# 36985                       Drama                the last duel
# 36986               Drama Western            news of the world
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 36982  Tom Cruise Miles Teller Jennifer Connelly Jose...
# 36983  Nicolas Cage Emma Stone Ryan Reynolds Joel Cra...
# 36984  Jennifer Hudson Forest Whitaker Marlon Wayans ...
# 36985  Matt Damon Adam Driver Jodie Comer Ridley Scot...
# 36986  Tom Hanks Helena Zengel Neil Sandilands Paul G...
#
# [36987 rows x 7 columns]

# %%
final_df = old_df.append(new_df21,ignore_index=True)

# %%
final_df
# Out:
#                                            director_name  \
# 0                                          John Lasseter
# 1                                           Joe Johnston
# 2                                          Howard Deutch
# 3                                        Forest Whitaker
# 4                                          Charles Shyer
# ...                                                  ...
# 37314                                     Matthew Vaughn
# 37315                                          Joel Coen
# 37316                                  Denzel Washington
# 37317                                     Erwin brothers
# 37318  Apichatpong Weerasethakul (director/acreenplay...
#
#                                             actor_1_name       actor_2_name  \
# 0                                              Tom Hanks          Tim Allen
# 1                                         Robin Williams      Jonathan Hyde
# 2                                         Walter Matthau        Jack Lemmon
# 3                                        Whitney Houston     Angela Bassett
# 4                                           Steve Martin       Diane Keaton
# ...                                                  ...                ...
# 37314                                      Ralph Fiennes     Gemma Arterton
# 37315                                  Denzel Washington  Frances McDormand
# 37316                                  Michael B. Jordan       Chanté Adams
# 37317                                       Zachary Levi        Anna Paquin
# 37318  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#           actor_3_name                                 genres  \
# 0          Don Rickles                Animation Comedy Family
# 1        Kirsten Dunst               Adventure Fantasy Family
# 2          Ann-Margret                         Romance Comedy
# 3       Loretta Devine                   Comedy Drama Romance
# 4         Martin Short                                 Comedy
# ...                ...                                    ...
# 37314       Rhys Ifans  Action Adventure Thriller War Mystery
# 37315    Bertie Carvel                              Drama War
# 37316  Jalon Christian                          Drama Romance
# 37317     Dennis Quaid                                  Drama
# 37318   Jeanne Balibar                  Drama Fantasy Mystery
#
#                        movie_title  \
# 0                        toy story
# 1                          jumanji
# 2                 grumpier old men
# 3                waiting to exhale
# 4      father of the bride part ii
# ...                            ...
# 37314               the king's man
# 37315       the tragedy of macbeth
# 37316         a journal for jordan
# 37317            american underdog
# 37318                      memoria
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 37314  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 37315  Denzel Washington Frances McDormand Bertie Car...
# 37316  Michael B. Jordan Chanté Adams Jalon Christian...
# 37317  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 37318  Apichatpong Weerasethakul (director/acreenplay...
#
# [37319 rows x 7 columns]

# %%
final_df.to_csv('main_updated_data.csv',index=False)
